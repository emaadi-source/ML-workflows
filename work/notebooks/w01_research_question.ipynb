# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I have chosen the **Refresh / Content Opportunity Scoring** lane.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# I selected the Refresh / Content Opportunity Scoring lane because it focuses on helping SEO teams identify which content pages should be reviewed first. Instead of reviewing thousands of pages manually, this approach prioritizes the pages with the highest opportunity for improvement using data-driven analysis. This problem aligns well with the available starter dataset and provides a strong foundation for building and evaluating machine learning models during the internship.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# This lane is suitable because the starter dataset already contains content performance metrics such as impressions, clicks, CTR, sessions, engagement rate, content age, trend direction, and average position. These features provide enough information to analyze page performance and develop a ranking system for recommending pages that deserve review.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work is intended to provide **decision support** by identifying and ranking content pages that are good candidates for review based on their performance data. The analysis will highlight patterns and opportunities observed in the available dataset, helping SEO teams prioritize which pages to review first.
#
# This work cannot prove that refreshing a page will increase traffic or rankings, nor can it predict Google's search algorithm or guarantee future performance. Any recommendations produced by this project should be treated as evidence-based suggestions that require human review before action is taken.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ y] Every section above is filled — markdown thinking AND the code that backs it
# - [ y] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ y] No client names, URLs, or private queries anywhere
# - [ y] My claims use careful words: observed, measured, directional, decision-support
# - [ y] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
